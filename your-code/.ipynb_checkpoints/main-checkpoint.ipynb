# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data
# Out:
#         Year  Month                      Supplier ItemCode  \
# 0       2017      4               ROYAL WINE CORP   100200
# 1       2017      4      SANTA MARGHERITA USA INC   100749
# 2       2017      4            JIM BEAM BRANDS CO    10103
# 3       2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4               ROYAL WINE CORP   101664
# ...      ...    ...                           ...      ...
# 128350  2018      2            ANHEUSER BUSCH INC     9997
# 128351  2018      2   COASTAL BREWING COMPANY LLC    99970
# 128352  2018      2       BOSTON BEER CORPORATION    99988
# 128353  2018      2                           NaN       BC
# 128354  2018      2                           NaN       WC
#
#                                     Description ItemType  RetailSales  \
# 0                             GAMLA CAB - 750ML     WINE         0.00
# 1          SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE         0.00
# ...

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
partition = data.groupby('ItemType').sum().iloc[:, 2:5].reset_index()

columns = partition.columns
for col in columns:
    if col == 'ItemType':
        pass
    else:
        partition_x = partition.loc[:,['ItemType',col]].sort_values(col, ascending=False)
        plt.bar(x=partition_x['ItemType'], height=partition_x[col])
        plt.ylabel(col)
        plt.xticks(rotation=90)
        plt.show();
partition
# Out:
#        ItemType  RetailSales  RetailTransfers  WarehouseSales
# 0          BEER    209763.11        234924.44      2437617.32
# 1       DUNNAGE         0.00             0.00       -45331.00
# 2          KEGS         0.00             0.00        43558.00
# 3        LIQUOR    309847.85        334176.41        33173.32
# 4   NON-ALCOHOL      8109.97          9058.37         8656.72
# 5           REF       281.34           171.92        -6754.00
# 6  STR_SUPPLIES       995.98          3594.70            0.00
# 7          WINE    313400.42        340710.51       433009.47

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data['TotalSales'] = data.RetailSales + data.WarehouseSales
data.groupby('Supplier').agg({'TotalSales':'sum'}).sort_values('TotalSales').tail(10).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Supplier'>

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data.groupby(['Year','Month']).agg({'RetailSales':'mean','RetailTransfers':'mean','WarehouseSales':'mean'}).plot(xlabel='Año y Mes', ylabel='Promedio', figsize=(15,10));

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data.groupby(['Year','Month']).agg({'RetailSales':'mean','RetailTransfers':'mean','WarehouseSales':'mean'}).plot(kind='bar',xlabel='Año y Mes', ylabel='Promedio', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Año y Mes', ylabel='Promedio'>

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
pd.pivot_table(data,values='RetailSales', columns='ItemType', index=['Year','Month'],aggfunc={'RetailSales':'sum'}).plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
pd.pivot_table(data,values='RetailSales', columns='ItemType', index=['Year','Month'], aggfunc={'RetailSales':'sum'}).plot(figsize=(16,8), kind='bar')
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(data=data, x='RetailSales', y='RetailTransfers', hue='ItemType')
# Out:
# <AxesSubplot:xlabel='RetailSales', ylabel='RetailTransfers'>

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.set(context='paper', style='whitegrid', rc={'figure.figsize': (8, 8)})
sns.pairplot(data.iloc[:, 5:10] , hue = 'ItemType');
