# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data
# Out:
#         Year  Month                              Supplier ItemCode  \
# 0       2017      4                       ROYAL WINE CORP   100200
# 1       2017      4              SANTA MARGHERITA USA INC   100749
# 2       2017      4                    JIM BEAM BRANDS CO    10103
# 3       2017      4          HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4                       ROYAL WINE CORP   101664
# 5       2017      4     REPUBLIC NATIONAL DISTRIBUTING CO   101680
# 6       2017      4                       ROYAL WINE CORP   101753
# 7       2017      4                    JIM BEAM BRANDS CO    10197
# 8       2017      4             STE MICHELLE WINE ESTATES   101974
# 9       2017      4             MONSIEUR TOUTON SELECTION   102083
# 10      2017      4                    JIM BEAM BRANDS CO    10243
# 11      2017      4                 BACCHUS IMPORTERS LTD    10246
# 12      2017      4                               MHW LTD    10266
# ...

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data1=data[['RetailSales', 'RetailTransfers','WarehouseSales', 'ItemType']].groupby(['ItemType']).sum()
data1.plot.bar()
plt.show()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
#data1 = data.groupby(['Supplier'])['RetailSales'].sort_values(by=['RetailSales'], ascending=False)
data['total']=data['RetailTransfers']+data['RetailSales']+data['WarehouseSales']
data1=data.groupby(['Supplier','ItemType']).sum().sort_values(by=['total'], ascending=False)['total'].head(10)
data1.plot.barh()
plt.show()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
ax = sns.lineplot(x = 'Month' ,y = 'RetailSales', data = data, palette='Set2')
ax = sns.lineplot(x = 'Month', y = 'RetailTransfers', data = data, palette='Set2')
ax = sns.lineplot(x = 'Month', y = 'WarehouseSales', data = data, palette='Set2')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
ax=data.groupby(['Month']).mean()[['RetailSales','RetailTransfers','WarehouseSales']]

ax.plot.bar()
plt.show()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data.groupby(['Year', 'Month','ItemType']).sum()[['RetailSales']]
# Out:
#                          RetailSales
# Year Month ItemType
# 2017 4     BEER                 0.00
#            LIQUOR               0.00
#            NON-ALCOHOL          0.00
#            REF                  0.00
#            STR_SUPPLIES         0.00
#            WINE                 0.00
#      5     BEER             25023.24
#            LIQUOR           35123.36
#            WINE             34546.89
#      6     BEER             27863.26
#            DUNNAGE              0.00
#            KEGS                 0.00
#            LIQUOR           35035.31
#            NON-ALCOHOL       1209.23
#            REF                 30.60
#            STR_SUPPLIES        89.22
#            WINE             33129.64
#      8     BEER             23030.13
#            DUNNAGE              0.00
#            KEGS                 0.00
#            LIQUOR           32186.04
#            NON-ALCOHOL       1091.28
#            REF                 19.54
#            STR_SUPPLIES        77.34
# ...

# %%
ax=data.groupby(['Year', 'Month','ItemType']).sum()[['RetailSales']]

ax=ax.plot()
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

plt.show()

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
ax=data.groupby(['Year', 'Month','ItemType']).sum()[['RetailSales']]

ax=ax.plot.bar()
plt.figure(figsize=(5,5))

ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

plt.show()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(x='RetailSales', y='RetailTransfers', data=data, hue='ItemCode')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3b944cc0cce4> in <module>
# ----> 1 sns.scatterplot(x='RetailSales', y='RetailTransfers', data=data, hue='ItemCode')
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1339         ax = plt.gca()
#    1340
# -> 1341     p.plot(ax, kwargs)
#    1342
#    1343     return ax
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     927         self.label_axes(ax)
#     928         if self.legend:
# --> 929             self.add_legend_data(ax)
#     930             handles, _ = ax.get_legend_handles_labels()
#     931             if handles:
#
# ...

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
# %matplotlib inline

pd.plotting.scatter_matrix(data)
plt.show()
