# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')

# %%
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Supplier', 'ItemCode', 'Description', 'ItemType',
#        'RetailSales', 'RetailTransfers', 'WarehouseSales'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Year                 int64
# Month                int64
# Supplier            object
# ItemCode            object
# Description         object
# ItemType            object
# RetailSales        float64
# RetailTransfers    float64
# WarehouseSales     float64
# dtype: object

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data2 =data[['RetailSales', 'RetailTransfers', 'WarehouseSales', 'ItemType']]
data2.groupby('ItemType')['RetailSales', 'RetailTransfers', 'WarehouseSales', 'ItemType'].sum()
# Out:
#               RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433009.47

# %%
bx = data2[['RetailSales', 'RetailTransfers', 'WarehouseSales', 'ItemType']].groupby(['ItemType']).sum()
bx.plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data3 = data[['Supplier', 'RetailSales', 'WarehouseSales']]
data3['SalesMix']= data3['RetailSales']+data3['WarehouseSales']
serie = data3.groupby('Supplier').agg(
    {'SalesMix':'sum',
})
top = serie.reset_index().sort_values('SalesMix', ascending=False).head(10)
top
# Out:
#                      Supplier   SalesMix
# 184    MILLER BREWING COMPANY  607646.04
# 69              CROWN IMPORTS  606532.53
# 15         ANHEUSER BUSCH INC  536415.33
# 139              HEINEKEN USA  339735.76
# 94         E & J GALLO WINERY  143050.62
# 78   DIAGEO NORTH AMERICA INC  111909.24
# 65       CONSTELLATION BRANDS   99441.27
# 38    BOSTON BEER CORPORATION   64194.16
# 330         YUENGLING BREWERY   63433.67
# 109   FLYING DOG BREWERY LLLP   57528.30

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

ax.barh(top['Supplier'],top['SalesMix'])
plt.show()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data4 = data[['Month', 'RetailSales', 'RetailTransfers', 'WarehouseSales']]

# %%
serie = data4.groupby('Month').agg(
    {'RetailSales':'mean',
     'RetailTransfers':'mean',
     'WarehouseSales':'mean'
})
serie = serie.reset_index()
serie
# Out:
#    Month  RetailSales  RetailTransfers  WarehouseSales
# 0      1     5.679413         5.574833       19.072137
# 1      2     5.939247         6.050136       20.229658
# 2      4     0.000000        15.707503        0.000000
# 3      5     7.038838         7.421817       27.310548
# 4      6     7.143914         6.950396       27.839069
# 5      8     6.409991         6.584726       28.122641
# 6      9     6.757254         6.419721       22.817909
# 7     10     6.549021         6.827827       22.289367
# 8     11     6.765496         7.103699       23.348862
# 9     12     9.078241         8.353759       21.169463

# %%
# multiple line plot
plt.plot( 'Month', 'RetailSales', data=serie, marker='',color='skyblue', linewidth=2)
plt.plot( 'Month', 'RetailTransfers', data=serie, marker='', color='Green', linewidth=2)
plt.plot( 'Month', 'WarehouseSales', data=serie, marker='', color='Red', linewidth=2)
plt.legend()
 
# Add titles
plt.title("Multi lines plot average sales per month", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Months")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
serie[['RetailSales', 'RetailTransfers', 'WarehouseSales']].plot.bar()
#bx.plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data5 = data.pivot_table(index=data[['Year', 'Month']], columns='ItemType', values='RetailSales', aggfunc={'RetailSales':'sum'})
data5.plot()

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data5.plot.bar()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
data7 = data[['RetailSales','RetailTransfers', 'ItemType']]
data7.head()
# Out:
#    RetailSales  RetailTransfers ItemType
# 0          0.0              1.0     WINE
# 1          0.0              1.0     WINE
# 2          0.0              8.0   LIQUOR
# 3          0.0              2.0   LIQUOR
# 4          0.0              4.0     WINE

# %%
sns.lmplot('RetailSales', 'RetailTransfers', hue='ItemType',data=data7)
#esta gráfica nos muestra mas informacion al trazar las lineas de tendencia

# %%
sns.scatterplot('RetailSales', 'RetailTransfers', hue='ItemType',data=data7)
#Aunque esta es la gráfica que piden, no muestra las lineas de tendencia aunque alcanza a ser mas amplia y mas clara que las anterior

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
data8= data[['Year', 'Month', 'RetailSales', 'RetailTransfers', 'WarehouseSales', 'ItemType']]

# %%
data8
# Out:
#         Year  Month  RetailSales  RetailTransfers  WarehouseSales  \
# 0       2017      4         0.00              1.0             0.0
# 1       2017      4         0.00              1.0             0.0
# 2       2017      4         0.00              8.0             0.0
# 3       2017      4         0.00              2.0             0.0
# 4       2017      4         0.00              4.0             0.0
# 5       2017      4         0.00              1.0             0.0
# 6       2017      4         0.00              1.0             0.0
# 7       2017      4         0.00             32.0             0.0
# 8       2017      4         0.00             26.0             0.0
# 9       2017      4         0.00              1.0             0.0
# 10      2017      4         0.00              3.0             0.0
# 11      2017      4         0.00              5.0             0.0
# 12      2017      4         0.00              4.0             0.0
# ...

# %%
sns.pairplot(data8)
#este scatterplot matrix, no esta separado por la columna de Item type

# %%
sns.pairplot(data8, hue ='ItemType')
#este scatterplot matrix, no esta separado por la columna de Item type
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-23-56407a8270d2> in <module>
# ----> 1 sns.pairplot(data8, hue ='ItemType')
#       2 #este scatterplot matrix, no esta separado por la columna de Item type
#
# c:\program files\python37\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# c:\program files\python37\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# ...
