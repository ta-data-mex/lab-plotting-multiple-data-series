# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('../data/liquor_store_sales.csv')
df.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data = df.groupby(['ItemType'], as_index=True)['RetailSales', 'RetailTransfers', 'WarehouseSales'].agg('sum').sort_values(by='ItemType')
data.plot(kind='bar', figsize=(20,15));

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data = df.groupby(['Supplier'], as_index=True)['RetailSales'].agg('sum')
data1 = data.sort_values(ascending=False)
data2 = data1.head(10)
data2.plot(kind='barh', figsize=(20,15), color='red');

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data_linea = df.groupby(['Month'], as_index=True)['RetailSales', 'RetailTransfers', 'WarehouseSales'].agg('mean')
data_linea.plot(kind='line', figsize=(10,5));

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data_linea = df.groupby(['Month'], as_index=True)['RetailSales', 'RetailTransfers', 'WarehouseSales'].agg('mean')
data_linea.plot(kind='bar', figsize=(10,5));

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data4 = pd.pivot_table(df, 
                      values='RetailSales',
                       columns = 'ItemType',
                      index=['Year', 'Month'],
                      aggfunc={'RetailSales':'sum'})
data4.plot(kind='line', figsize=(20,10));

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data4 = pd.pivot_table(df, 
                      values='RetailSales',
                       columns = 'ItemType',
                      index=['Year', 'Month'],
                      aggfunc={'RetailSales':'sum'})
data4.plot(kind='bar', figsize=(20,15), width = 3);

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(df.RetailSales,df.RetailTransfers, hue=df.ItemType)
# Out:
# <AxesSubplot:xlabel='RetailSales', ylabel='RetailTransfers'>

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
df.info()

#data[data.ItemType.isnull()==True]
#data = data.drop(66439)
#data = data.reset_index()

sns.pairplot(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             128355 non-null  int64
#  1   Month            128355 non-null  int64
#  2   Supplier         128331 non-null  object
#  3   ItemCode         128355 non-null  object
#  4   Description      128355 non-null  object
#  5   ItemType         128354 non-null  object
#  6   RetailSales      128355 non-null  float64
#  7   RetailTransfers  128355 non-null  float64
#  8   WarehouseSales   128355 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 6.9+ MB

# %%
def noise(x):
    return x+5*np.random.randint(0,3)

df['RetailTransfers'] = df['RetailTransfers'].apply(noise)

# %%
plt.figure()

plt.subplot(3,3,1)
sns.scatterplot('RetailSales','RetailSales', hue='ItemType', data=df, label=False)

plt.subplot(3,3,2)
sns.scatterplot('RetailSales','RetailTransfers', data=df, hue='ItemType', label=False)


plt.subplot(3,3,3)
sns.scatterplot('RetailSales','WarehouseSales', data=df, hue='ItemType', label=False)


plt.subplot(3,3,4)
sns.scatterplot('RetailTransfers','RetailSales', hue='ItemType', data=df, label=False)


plt.subplot(3,3,5)
sns.scatterplot('RetailTransfers','RetailTransfers', data=df, hue='ItemType', label=False)


plt.subplot(3,3,6)
sns.scatterplot('RetailTransfers','WarehouseSales', data=df, hue='ItemType', label=False)


plt.subplot(3,3,7)
sns.scatterplot('WarehouseSales','RetailSales', hue='ItemType', data=df, label=False)


plt.subplot(3,3,8)
sns.scatterplot('WarehouseSales','RetailTransfers', hue='ItemType', data=df, label=False)


plt.subplot(3,3,9)
sns.scatterplot('WarehouseSales','WarehouseSales', data=df, hue='ItemType', label=False)
# Out:
# <AxesSubplot:xlabel='WarehouseSales', ylabel='WarehouseSales'>
