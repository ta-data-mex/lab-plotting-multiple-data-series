# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(15,10)},style='whitegrid')

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.describe()
# Out:
#                 Year          Month    RetailSales  RetailTransfers  \
# count  128355.000000  128355.000000  128355.000000    128355.000000
# mean     2017.206030       7.079303       6.563037         7.188161
# std         0.404454       3.645826      28.924944        30.640156
# min      2017.000000       1.000000      -6.490000       -27.660000
# 25%      2017.000000       5.000000       0.000000         0.000000
# 50%      2017.000000       8.000000       0.330000         0.000000
# 75%      2017.000000      10.000000       3.250000         4.000000
# max      2018.000000      12.000000    1616.600000      1587.990000
#
#        WarehouseSales
# count   128355.000000
# mean        22.624213
# std        239.693277
# min      -4996.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max      16271.750000

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
#sns.lmplot()
#graf1 = data[["RetailSales", "RetailTransfers", "WarehouseSales"]].plot.bar()
#data.plot.bar()

data1 = data.groupby(["ItemType"]).sum()

# %%
data1
# Out:
#                    Year   Month  RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER           33132676  115830    209763.11        234924.44      2437617.32
# DUNNAGE           64552     236         0.00             0.00       -45331.00
# KEGS            7338694   27033         0.00             0.00        43558.00
# LIQUOR         57282701  197353    309847.85        334176.41        33173.32
# NON-ALCOHOL     1266826    4426      8109.97          9058.37         8656.72
# REF              102879     385       281.34           171.92        -6754.00
# STR_SUPPLIES     213823     774       995.98          3594.70            0.00
# WINE          159514312  562617    313400.42        340710.51       433009.47

# %%
data1[["RetailSales", "RetailTransfers", "WarehouseSales"]].plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data
# Out:
#         Year  Month                              Supplier ItemCode  \
# 0       2017      4                       ROYAL WINE CORP   100200
# 1       2017      4              SANTA MARGHERITA USA INC   100749
# 2       2017      4                    JIM BEAM BRANDS CO    10103
# 3       2017      4          HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4                       ROYAL WINE CORP   101664
# 5       2017      4     REPUBLIC NATIONAL DISTRIBUTING CO   101680
# 6       2017      4                       ROYAL WINE CORP   101753
# 7       2017      4                    JIM BEAM BRANDS CO    10197
# 8       2017      4             STE MICHELLE WINE ESTATES   101974
# 9       2017      4             MONSIEUR TOUTON SELECTION   102083
# 10      2017      4                    JIM BEAM BRANDS CO    10243
# 11      2017      4                 BACCHUS IMPORTERS LTD    10246
# 12      2017      4                               MHW LTD    10266
# ...

# %%
#INSTRUCCION
#Create total sales varible (retail sales + warehouse sales)
#Seleciona el top ten
#Crea la gráfica

data["TotalSales"] = data["RetailSales"] + data["WarehouseSales"]

# %%
data.groupby(["Supplier"]).sum().sort_values("TotalSales", ascending = False).head(10).TotalSales.plot.barh()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
#mult_line = data[["RetailSales", "RetailTransfers", "WarehouseSales"]].groupby(["Year"]).agg("mean").plot.bar()

mean_line = data.groupby(["Month"]).mean().drop(["Year", "TotalSales"], axis=1).plot.line()


#mean_line.plot.bar()

#vehicles_mean = vehicles[["Highway MPG", "City MPG", "Drivetrain"]].groupby(["Drivetrain"]).agg("mean")
#vehicles_mean.plot.bar()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
mean_line = data.groupby(["Month"]).mean().drop(["Year", "TotalSales"], axis=1).plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
#Aqui no estoy seguir qué me están pidiendo
data.groupby(["Year", "Month"]).sum().drop(["RetailTransfers", "TotalSales", "WarehouseSales"], axis=1).plot.line()

# %%
sns.lineplot(x='Month', y='RetailSales', hue='ItemType', data=data, estimator=sum)

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
sns.barplot(x='Month', y='RetailSales', hue='ItemType', data=data, estimator=sum)

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(x="RetailSales", y="RetailTransfers", hue="ItemType", data=data)

#sns.scatterplot(x="CO2 Emission Grams/Mile", y="Highway MPG", hue="Drivetrain", data=data)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(hue='ItemType', data=data)
