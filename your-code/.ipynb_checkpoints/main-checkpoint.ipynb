# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data
# Out:
#         Year  Month                              Supplier ItemCode  \
# 0       2017      4                       ROYAL WINE CORP   100200
# 1       2017      4              SANTA MARGHERITA USA INC   100749
# 2       2017      4                    JIM BEAM BRANDS CO    10103
# 3       2017      4          HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4                       ROYAL WINE CORP   101664
# 5       2017      4     REPUBLIC NATIONAL DISTRIBUTING CO   101680
# 6       2017      4                       ROYAL WINE CORP   101753
# 7       2017      4                    JIM BEAM BRANDS CO    10197
# 8       2017      4             STE MICHELLE WINE ESTATES   101974
# 9       2017      4             MONSIEUR TOUTON SELECTION   102083
# 10      2017      4                    JIM BEAM BRANDS CO    10243
# 11      2017      4                 BACCHUS IMPORTERS LTD    10246
# 12      2017      4                               MHW LTD    10266
# ...

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
ventas = data.groupby(['ItemType'])[['RetailSales','RetailTransfers','WarehouseSales']].sum()#.reset_index()
ventas
# Out:
#               RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433009.47

# %%
ventas.plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
ventas1 = data.groupby(['Supplier'])[['RetailSales','RetailTransfers','WarehouseSales']].sum()
ventas1['Total Sales'] = (ventas1.RetailSales + ventas1.RetailTransfers + ventas1.WarehouseSales)
ventas1.groupby(['Supplier'])["Total Sales"].sum().sort_values(ascending = False)[:10].plot.barh()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data.groupby(["Month"])[["RetailSales", "RetailTransfers", "WarehouseSales"]].agg("mean").plot(kind="line", figsize = (10,7))
plt.ylabel('Sales', fontsize=15)
plt.xlabel('Months', fontsize=15)
# Out:
# Text(0.5, 0, 'Months')

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data.groupby(["Month"])[["RetailSales", "RetailTransfers", "WarehouseSales"]].agg("mean").plot(kind="bar", figsize = (10,7))
plt.ylabel('Sales', fontsize=15)
plt.xlabel('Months', fontsize=15)
# Out:
# Text(0.5, 0, 'Months')

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data.groupby(['Year','Month','ItemType'])['RetailSales'].sum().plot(kind="line", figsize = (20,7))

# %%
data.sort_values(by=['Year', 'Month', 'ItemType']).plot(x=data.ItemType)
#intentar con tabla pivote
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-3e63226bc72a> in <module>
# ----> 1 data.sort_values(by=['Year', 'Month', 'ItemType']).plot(x=data.ItemType)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ...

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data.groupby(['Year','Month','ItemType'])['RetailSales'].sum().plot(kind="bar", figsize = (20,7))

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.set()
sns.lmplot(x='RetailSales', y='RetailTransfers', hue='ItemType', fit_reg = False, data=data)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(hue='ItemType', data=data)
